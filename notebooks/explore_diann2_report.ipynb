# %%
import pandas as pd

df = pd.read_parquet("/data/48/zshang/DIA-Aspire-Rescore/data/lib-base-result-first-pass.parquet")

# %%
df["RT"].head()
# Out:
# 0    90.303909
# 1    90.442459
# 2    59.062805
# 3    59.042984
# 4    25.684074
# Name: RT, dtype: float32

# %%
# drop index, to parquet
df.iloc[[0, 113, 726, 729]].to_parquet("/data/48/zshang/DIA-Aspire-Rescore/tests/test_data/test_diann2.parquet")
df.iloc[[0, 113, 726, 729]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 729
# Columns: 117 entries, Run.Index to Fr.11.Score
# dtypes: float32(77), int64(17), object(23)
# memory usage: 2.5+ KB
